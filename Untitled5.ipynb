# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoMedrano128/EPPL-rea-de-un-triangulo-rect-ngulo/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Santiago Medrano NL = 37 Fecha 25/Mar/2026 ✈
# ---
# # Calcular Area y perimetro de un triangulo ⏰
# ---
# #![Logo de Markdown](https://raw.githubusercontent.com/SantiagoMedrano128/EPPL-rea-de-un-triangulo-rect-ngulo/refs/heads/main/area%20triangulo%20rectangulo.PNG)
# ---
# ## Formula para calcular area
# # $A = b * h / 2  $
# ---
# # Datos de entrada
# $b$ ?, $h$ ?
# ---
# # Diagrama de flujo LucidChart
# #![Logo de Markdown](https://raw.githubusercontent.com/SantiagoMedrano128/EPPL-rea-de-un-triangulo-rect-ngulo/refs/heads/main/Diagrama%20de%20flujo%20LucidChart.PNG)

# %%
# Calcular el area de un Triangulo Rectangulo
# Variables A, b, h
# Formula A = b * h / 2
print("Calculando el area de un triangulo rectangulo")
h = float(input("Ingrese el valor de la altura: "))
b = float(input("Ingrese el valor de la base: "))
A = b * h / 2
print("El area del triangulo rectangulo es: ", A)
print("Santiago Medrano NL = 37")
# Out:
# Calculando el area de un triangulo rectangulo
# Ingrese el valor de la base: 6
# Ingrese el valor de la altura: 9
# El area del triangulo rectangulo es:  27.0
# Santiago Medrano NL = 37

# %% [markdown]
# # Relacion entre codigo y DF en tldraw
# # ![Logo de Markdown](https://raw.githubusercontent.com/SantiagoMedrano128/EPPL-rea-de-un-triangulo-rect-ngulo/refs/heads/main/Relacion%20codigo%20diagrama.PNG)
